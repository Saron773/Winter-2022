# %% [markdown]
# <a href="https://colab.research.google.com/github/Saron773/Winter-2022/blob/main/NYC_311_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('https://raw.githubusercontent.com/CunyLaguardiaDataAnalytics/datasets/master/311_Service_Requests_from_2019May.csv')
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (6) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.head()
# Out:
#    Unique Key  ...                                  Location
# 0    42680103  ...  (40.682565064146196, -73.81406015056832)
# 1    42530481  ...  (40.738790792032844, -74.00022373020307)
# 2    42527619  ...   (40.79804015465285, -73.96930001020544)
# 3    42526597  ...   (40.67590510222738, -73.86665990579837)
# 4    42526595  ...   (40.76536704921336, -73.93154011254339)
#
# [5 rows x 21 columns]

# %%
df[['Borough', 'Agency']].sort_values(by='Borough')
# Out:
#            Borough Agency
# 55688        BRONX    DOT
# 33107        BRONX    HPD
# 56021        BRONX    DOT
# 33108        BRONX    HPD
# 45647        BRONX   NYPD
# ...            ...    ...
# 16692  Unspecified    DOT
# 12585  Unspecified   DCAS
# 54364  Unspecified    DOT
# 5898   Unspecified    HRA
# 38814  Unspecified    DOF
#
# [69637 rows x 2 columns]

# %%
df[['Borough', 'Agency']].sort_values(by='Borough').nunique()
# Out:
# Borough     6
# Agency     20
# dtype: int64

# %%
df.shape
# Out:
# (69637, 21)

# %%
df.columns
# Out:
# Index(['Unique Key', 'Created Date', 'Closed Date', 'Agency', 'Complaint Type',
#        'Location Type', 'Incident Zip', 'Incident Address', 'Street Name',
#        'Address Type', 'City', 'Landmark', 'Facility Type', 'Status',
#        'Due Date', 'Resolution Description', 'BBL', 'Borough', 'Latitude',
#        'Longitude', 'Location'],
#       dtype='object')

# %%
df.groupby(['Borough'])['Unique Key'].count()
# Out:
# Borough
# BRONX            10925
# BROOKLYN         22247
# MANHATTAN        13133
# QUEENS           18623
# STATEN ISLAND     3848
# Unspecified        861
# Name: Unique Key, dtype: int64

# %%
df.groupby(['Borough'])

# %%
df.groupby(['Borough'])['Unique Key'].count().sort_values(ascending = True).plot(kind = 'bar')

# %%
borough_df = df.groupby(['Borough'])['Unique Key'].count()

# %%
type(borough_df)
# Out:
# pandas.core.series.Series

# %%
borough_df.values
# Out:
# array([10925, 22247, 13133, 18623,  3848,   861])

# %%
borough_df.index
# Out:
# Index(['BRONX', 'BROOKLYN', 'MANHATTAN', 'QUEENS', 'STATEN ISLAND',
#        'Unspecified'],
#       dtype='object', name='Borough')

# %%
plt.ylabel = 'Frequency'
plt.xlabel = 'Borough'

# %%
borough_df.plot()

# %%
borough_df.plot(kind = 'pie')

# %%
borough_agency_df = df[['Borough', 'Agency', 'Complaint Type']]

# %%
borough_agency_df.shape
# Out:
# (69637, 3)

# %%
borough_agency_df.head()
# Out:
#      Borough Agency  Complaint Type
# 0     QUEENS    DEP    Water System
# 1  MANHATTAN  DOHMH  Food Poisoning
# 2  MANHATTAN  DOHMH  Food Poisoning
# 3   BROOKLYN  DOHMH  Food Poisoning
# 4     QUEENS  DOHMH  Food Poisoning

# %%
column_names = ['Borough', 'Agency', 'Complaint Type', 'Facility Type', 'City', 'Resolution Description']

# %%
new_df = df[column_names]

# %%
new_df.head()
# Out:
#      Borough  ...                             Resolution Description
# 0     QUEENS  ...  The Department of Environment Protection inspe...
# 1  MANHATTAN  ...  Callers should contact the DOHMH Foodborne Ill...
# 2  MANHATTAN  ...  The Department of Health and Mental Hygiene wi...
# 3   BROOKLYN  ...  The Department of Health and Mental Hygiene wi...
# 4     QUEENS  ...  The Department of Health and Mental Hygiene wi...
#
# [5 rows x 6 columns]

# %% [markdown]
# #Filtering

# %%
new_DEP_Agency_df = new_df[new_df['Agency']=='DEP']

# %%
new_DEP_Agency_df.head()
# Out:
#           Borough  ...                             Resolution Description
# 0          QUEENS  ...  The Department of Environment Protection inspe...
# 10       BROOKLYN  ...  The Department of Environmental Protection has...
# 11       BROOKLYN  ...  The Department of Environmental Protection did...
# 24          BRONX  ...  The Department of Environmental Protection did...
# 27  STATEN ISLAND  ...  The Department of Environmental Protection inv...
#
# [5 rows x 6 columns]

# %%
df.groupby('Agency')['Unique Key'].count().sort_values(ascending = True)
# Out:
# Agency
# TAX          6
# ACS          8
# DOITT       12
# DCAS        26
# DOE         44
# EDC         61
# DFTA       226
# HRA        238
# DCA        385
# DHS        476
# TLC        761
# DOF       1259
# DOHMH     1868
# DPR       3065
# DOB       4150
# DEP       5179
# DOT       8208
# HPD      11215
# DSNY     11262
# NYPD     21188
# Name: Unique Key, dtype: int64

# %%
new_TAX_Agency_df = new_df[new_df['Agency']=='TAX']

# %%
new_TAX_Agency_df
# Out:
#            Borough  ...                             Resolution Description
# 821    Unspecified  ...  Your comments have been submitted to the Tax C...
# 2765   Unspecified  ...  Your comments have been submitted to the Tax C...
# 11819  Unspecified  ...  Your comments have been submitted to the Tax C...
# 30496  Unspecified  ...  Your comments have been submitted to the Tax C...
# 30583  Unspecified  ...  Your comments have been submitted to the Tax C...
#
# [5 rows x 6 columns]

# %%
new_ACS_Agency_df = new_df[new_df['Agency']=='ACS']

# %%
new_ACS_Agency_df
# Out:
#            Borough  ...                             Resolution Description
# 2750   Unspecified  ...  Your comments have been submitted to the Admin...
# 15374  Unspecified  ...  Your comments have been submitted to the Admin...
# 34317  Unspecified  ...  Your comments have been submitted to the Admin...
# 37194  Unspecified  ...  Your comments have been submitted to the Admin...
# 40066  Unspecified  ...  Your comments have been submitted to the Admin...
# 42251  Unspecified  ...  Your comments have been submitted to the Admin...
# 60836  Unspecified  ...  Your comments have been submitted to the Admin...
# 64139  Unspecified  ...  Your comments have been submitted to the Admin...
#
# [8 rows x 6 columns]

# %%
new_DOITT_Agency_df = new_df[new_df['Agency']=='DOITT']

# %%
new_DOITT_Agency_df
# Out:
#          Borough  ...                             Resolution Description
# 1437      QUEENS  ...  The phone company has already notified the Pub...
# 14025  MANHATTAN  ...  Both preliminary and follow-up inspections hav...
# 23435   BROOKLYN  ...  After a follow-up inspection, the graffiti/lit...
# 24742      BRONX  ...  Both preliminary and follow-up inspections hav...
# 26274  MANHATTAN  ...  Both preliminary and follow-up inspections hav...
# 37460      BRONX  ...  The Department of Information Technology and T...
# 43376  MANHATTAN  ...  Upon preliminary inspection, the phone was fou...
# 48452     QUEENS  ...  Both preliminary and follow-up inspections hav...
# 49756  MANHATTAN  ...  At time of first inspection, there was no evid...
# 54869  MANHATTAN  ...  Both preliminary and follow-up inspections hav...
# 65140     QUEENS  ...  Upon preliminary inspection, the phone was fou...
# 66043  MANHATTAN  ...  At time of first inspection, there was no evid...
#
# [12 rows x 6 columns]

# %%
new_DCAS_Agency_df = new_df[new_df['Agency']=='DCAS']

# %%
new_DCAS_Agency_df.head()
# Out:
#            Borough  ...                             Resolution Description
# 2379   Unspecified  ...  Your comments have been submitted to the Depar...
# 8278   Unspecified  ...  Your comments have been submitted to the Depar...
# 11690  Unspecified  ...  Your comments have been submitted to the Depar...
# 12585  Unspecified  ...  Your comments have been submitted to the Depar...
# 17288  Unspecified  ...  Your comments have been submitted to the Depar...
#
# [5 rows x 6 columns]

# %%
new_DOE_Agency_df = new_df[new_df['Agency']=='DOE']

# %%
new_DOE_Agency_df.head()
# Out:
#         Borough  ...                             Resolution Description
# 32       QUEENS  ...  The Department of Education completed the work...
# 492       BRONX  ...  The Department of Education completed the work...
# 818      QUEENS  ...  The Department of Education completed the work...
# 6006      BRONX  ...  The Department of Education completed the work...
# 13121  BROOKLYN  ...  The Department of Education completed the work...
#
# [5 rows x 6 columns]

# %%
new_EDC_Agency_df = new_df[new_df['Agency']=='EDC']

# %%
new_EDC_Agency_df.head()
# Out:
#          Borough  ...                             Resolution Description
# 12256     QUEENS  ...  Your complaint has been submitted to the New Y...
# 13261   BROOKLYN  ...  Your complaint has been submitted to the New Y...
# 15196  MANHATTAN  ...  Your complaint has been submitted to the New Y...
# 28515  MANHATTAN  ...  Your complaint has been submitted to the New Y...
# 28862  MANHATTAN  ...  Your complaint has been submitted to the New Y...
#
# [5 rows x 6 columns]

# %%
new_DFTA_Agency_df = new_df[new_df['Agency']=='DFTA']

# %%
new_DFTA_Agency_df.head()
# Out:
#         Borough  ...                             Resolution Description
# 1213      BRONX  ...  The Department for the Aging contacted you and...
# 1518     QUEENS  ...  The Department for the Aging contacted you and...
# 1723  MANHATTAN  ...  The Department for the Aging contacted you and...
# 1849  MANHATTAN  ...  The Department for the Aging contacted you and...
# 2004   BROOKLYN  ...  The Department for the Aging contacted you and...
#
# [5 rows x 6 columns]

# %%
new_HRA_Agency_df = new_df[new_df['Agency']=='HRA']

# %%
new_HRA_Agency_df.head()
# Out:
#           Borough  ...                             Resolution Description
# 348   Unspecified  ...  The Human Resources Administration received yo...
# 1438  Unspecified  ...  The Human Resources Administration received yo...
# 1696  Unspecified  ...  The Human Resources Administration received yo...
# 2225  Unspecified  ...  The Human Resources Administration received yo...
# 2421  Unspecified  ...  The Human Resources Administration received yo...
#
# [5 rows x 6 columns]

# %%
new_DCA_Agency_df = new_df[new_df['Agency']=='DCA']

# %%
new_DCA_Agency_df.head()

# %%
new_DHS_Agency_df = new_df[new_df['Agency']=='DHS']

# %%
new_DHS_Agency_df.head()
# Out:
#        Borough  ...                             Resolution Description
# 273     QUEENS  ...  The individual was found and outreach assistan...
# 794  MANHATTAN  ...  The mobile outreach response team went to the ...
# 810  MANHATTAN  ...  The mobile outreach response team offered serv...
# 882   BROOKLYN  ...  The mobile outreach response team offered serv...
# 962   BROOKLYN  ...  The Department of Homeless Services has review...
#
# [5 rows x 6 columns]

# %%
new_TLC_Agency_df = new_df[new_df['Agency']=='TLC']

# %%
new_TLC_Agency_df.head()
# Out:
#            Borough  ...                             Resolution Description
# 124      MANHATTAN  ...  Your report has been sent to the Taxi and Limo...
# 281       BROOKLYN  ...  The Taxi and Limousine Commission (TLC) has re...
# 355       BROOKLYN  ...  The Taxi and Limousine Commission (TLC) has re...
# 406  STATEN ISLAND  ...  The Taxi and Limousine Commission (TLC) has re...
# 497      MANHATTAN  ...  The Taxi and Limousine Commission was unable t...
#
# [5 rows x 6 columns]

# %%
new_DOF_Agency_df = new_df[new_df['Agency']=='DOF']

# %%
new_DOF_Agency_df.head()

# %%
new_DOHMH_Agency_df = new_df[new_df['Agency']=='DOHMH']

# %%
new_DOHMH_Agency_df.head()

# %%
new_DPR_Agency_df = new_df[new_df['Agency']=='DPR']

# %%
new_DPR_Agency_df.head()

# %%
new_DOB_Agency_df = new_df[new_df['Agency']=='DOB']

# %%
new_DOB_Agency_df.head()
# Out:
#        Borough  ...                             Resolution Description
# 19    BROOKLYN  ...  The Department of Buildings attempted to inves...
# 41    BROOKLYN  ...  The Department of Buildings attempted to inves...
# 44    BROOKLYN  ...  The Department of Buildings reviewed this comp...
# 92   MANHATTAN  ...  The Department of Buildings reviewed this comp...
# 110   BROOKLYN  ...  The Department of Buildings attempted to inves...
#
# [5 rows x 6 columns]

# %%
new_DOT_Agency_df = new_df[new_df['Agency']=='DOT']

# %%
new_DOT_Agency_df.head()
# Out:
#        Borough  ...                             Resolution Description
# 68   MANHATTAN  ...  The  Department of Transportation inspected th...
# 90    BROOKLYN  ...  Service Request status for this request is ava...
# 93      QUEENS  ...  Service Request status for this request is ava...
# 96    BROOKLYN  ...  Service Request status for this request is ava...
# 102  MANHATTAN  ...  The Department of Transportation inspected the...
#
# [5 rows x 6 columns]

# %%
new_HPD_Agency_df = new_df[new_df['Agency']=='HPD']

# %%
new_HPD_Agency_df.head()
# Out:
#       Borough  ...                             Resolution Description
# 13  MANHATTAN  ...  The Department of Housing Preservation and Dev...
# 14  MANHATTAN  ...  The Department of Housing Preservation and Dev...
# 22  MANHATTAN  ...  The Department of Housing Preservation and Dev...
# 25      BRONX  ...  The Department of Housing Preservation and Dev...
# 40      BRONX  ...  The Department of Housing Preservation and Dev...
#
# [5 rows x 6 columns]

# %%
new_DSNY_Agency_df = new_df[new_df['Agency']=='DSNY']

# %%
new_DSNY_Agency_df.head()
# Out:
#       Borough  ...                             Resolution Description
# 17  MANHATTAN  ...  The Department of Sanitation investigated this...
# 20   BROOKLYN  ...                                                NaN
# 21  MANHATTAN  ...  The Department of Sanitation investigated this...
# 72   BROOKLYN  ...  The Department of Sanitation did not find any ...
# 78  MANHATTAN  ...                                                NaN
#
# [5 rows x 6 columns]

# %%
new_NYPD_Agency_df = new_df[new_df['Agency']=='NYPD']

# %%
new_NYPD_Agency_df.head()
# Out:
#       Borough  ...                             Resolution Description
# 12  MANHATTAN  ...  Your request can not be processed at this time...
# 15  MANHATTAN  ...  The Police Department responded to the complai...
# 16   BROOKLYN  ...  The Police Department responded to the complai...
# 18      BRONX  ...  The Police Department issued a summons in resp...
# 23   BROOKLYN  ...  The Police Department responded to the complai...
#
# [5 rows x 6 columns]

# %%
new_TAX_Agency_df.head()
# Out:
#            Borough  ...                             Resolution Description
# 821    Unspecified  ...  Your comments have been submitted to the Tax C...
# 2765   Unspecified  ...  Your comments have been submitted to the Tax C...
# 11819  Unspecified  ...  Your comments have been submitted to the Tax C...
# 30496  Unspecified  ...  Your comments have been submitted to the Tax C...
# 30583  Unspecified  ...  Your comments have been submitted to the Tax C...
#
# [5 rows x 6 columns]
